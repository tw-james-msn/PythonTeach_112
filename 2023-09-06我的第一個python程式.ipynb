# %%
# 常數

# 數值常數
# --> 1、2、11111、1.23456E+3(1234.56)

# 文字(字串)常數
# --> '你好'、"2023年"、'李大仁'
# '李大仁'
# "男"
# '他是一個大"帥哥"！'
# '047123456'


# 變數(varible)的使用
tax=31.7

# 表達示(運算式)，經過計(運)算之後可以得到一個「值」
# 100*tax
# 200*tax
# 500*tax

# 1+1
# 5-2
# 4*5
# 8/4
# 2**3

# (1+2)*(3+(4-1)**(3-1))

# %%
PI = 3.14
r = 2
a = r**2 * PI

print( 111 , 222)
print( r , a)
print( '求圓面積' , '平方公分')

print('半徑', r , '公分的圓面積是' , a , '平方公分')
# Out:
# 111 222
# 2 12.56
# 求圓面積 平方公分
# 半徑 2 公分的圓面積是 12.56 平方公分

# %%
x = 1+1
y = '你好我是' + '李大仁'

print(x)
print('='*20)
print(y)
# Out:
# 2
# ...
# 你好我是李大仁
